# %% [markdown]
# <a href="https://colab.research.google.com/github/Hiero-o/cp_01_tritiack/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello, World!

# %%
import pandas as pd
